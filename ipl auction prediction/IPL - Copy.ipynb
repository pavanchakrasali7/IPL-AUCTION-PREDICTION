# %% [markdown]
# # <center>Predict IPL Player Value

# %% [markdown]
# ### Importing Libraries

# %%
import pandas as pd
import warnings
warnings.simplefilter(action='ignore')

# %% [markdown]
# ### Reading the IPL data of the year 2008

# %%
ipl_08=pd.read_csv("C:\\Users\\pavan\\OneDrive\\Desktop\\final project\\Ipl Data\\2008.csv")
ipl_08.head()

# %% [markdown]
# ### Reading the IPL data of the year 2009

# %%
ipl_09=pd.read_csv("C:\\Users\\pavan\\OneDrive\\Desktop\\final project\\Ipl Data\\2009.csv")
ipl_09.head()

# %% [markdown]
# ### Reading the IPL data of the year 2010

# %%
ipl_10=pd.read_csv("C:\\Users\\pavan\\OneDrive\\Desktop\\final project\\Ipl Data\\2010.csv")
ipl_10.head()

# %% [markdown]
# ### Reading the IPL data of the year 2011

# %%
ipl_11=pd.read_csv("C:\\Users\\pavan\\OneDrive\\Desktop\\final project\\Ipl Data\\2011.csv")
ipl_11.head()

# %% [markdown]
# ### Reading the IPL data of the year 2012

# %%
ipl_12=pd.read_csv("C:\\Users\\pavan\\OneDrive\\Desktop\\final project\\Ipl Data\\2012.csv")
ipl_12.head()

# %% [markdown]
# ### Reading the IPL data of the year 2013

# %%
ipl_13=pd.read_csv("C:\\Users\\pavan\\OneDrive\\Desktop\\final project\\Ipl Data\\2013.csv")
ipl_13.head()

# %% [markdown]
# ### Reading the IPL data of the year 2014

# %%
ipl_14=pd.read_csv("C:\\Users\\pavan\\OneDrive\\Desktop\\final project\\Ipl Data\\2014.csv")
ipl_14.head()

# %% [markdown]
# ### Reading the IPL data of the year 2015

# %%
ipl_15=pd.read_csv("C:\\Users\\pavan\\OneDrive\\Desktop\\final project\\Ipl Data\\2015.csv")
ipl_15.head()

# %% [markdown]
# ### Reading the IPL data of the year 2016

# %%
ipl_16=pd.read_csv("C:\\Users\\pavan\\OneDrive\\Desktop\\final project\\Ipl Data\\2016.csv")
ipl_16.head()

# %% [markdown]
# ### Reading the IPL data of the year 2017

# %%
ipl_17=pd.read_csv("C:\\Users\\pavan\\OneDrive\\Desktop\\final project\\Ipl Data\\2017.csv")
ipl_17.head()

# %% [markdown]
# ### Reading the IPL data of the year 2018

# %%
ipl_18=pd.read_csv("C:\\Users\\pavan\\OneDrive\\Desktop\\final project\\Ipl Data\\2018.csv")
ipl_18.head()

# %% [markdown]
# ### Reading the IPL data of the year 2019

# %%
ipl_19=pd.read_csv("C:\\Users\\pavan\\OneDrive\\Desktop\\final project\\Ipl Data\\2019.csv")
ipl_19.head()

# %% [markdown]
# ### Reading the IPL data of the year 2020

# %%
ipl_20=pd.read_csv("C:\\Users\\pavan\\OneDrive\\Desktop\\final project\\Ipl Data\\2020.csv")
ipl_20.head()

# %% [markdown]
# ### Reading the IPL data of the year 2021

# %%
ipl_21=pd.read_csv("C:\\Users\\pavan\\OneDrive\\Desktop\\final project\\Ipl Data\\2021.csv")
ipl_21.head()

# %% [markdown]
# ### Reading the IPL data of the year 2022

# %%
ipl_22=pd.read_csv("C:\\Users\\pavan\\OneDrive\\Desktop\\final project\\Ipl Data\\2022.csv")
ipl_22.head()

# %% [markdown]
# ### Reading the IPL data of the year 2023

# %%
ipl_23=pd.read_csv("C:\\Users\\pavan\\OneDrive\\Desktop\\final project\\Ipl Data\\2023.csv")
ipl_23.head()

# %% [markdown]
# ### Concatinating the IPL data of all the years from teh year 2008 to 2023, and considering it the training data to predict the value of the player

# %%
ipl_full = pd.concat([ipl_08,ipl_09,ipl_10,ipl_11,ipl_12,ipl_13,ipl_14,ipl_15,ipl_16,ipl_17,ipl_18,ipl_19,ipl_20,ipl_21,ipl_22,ipl_23], ignore_index=True)

# %%
ipl_full
# Out:
#       Rank         Player                   Team  RAA   Wins  EFscore  \
# 0        1       SE Marsh        Kings XI Punjab  377  1.355    0.231
# 1        2      SR Watson       Rajasthan Royals  347  1.250    0.297
# 2        3  Sohail Tanvir       Rajasthan Royals  294  1.059    0.194
# 3        4      G Gambhir       Delhi Daredevils  216  0.776    0.160
# 4        5       GC Smith       Rajasthan Royals  202  0.725    0.139
# ...    ...            ...                    ...  ...    ...      ...
# 2689   204      CJ Jordan         Mumbai Indians -195 -0.686    0.019
# 2690   205       UT Yadav  Kolkata Knight Riders -195 -0.687    0.015
# 2691   206      JO Holder       Rajasthan Royals -213 -0.749    0.026
# 2692   207      SP Narine  Kolkata Knight Riders -218 -0.766    0.067
# 2693   208      RD Chahar           Punjab Kings -219 -0.773    0.056
#
#           Salary       Value
# 0            NaN  $1,270,355
# 1       $125,000  $1,209,660
# 2            NaN  $1,099,252
# 3       $725,000    $935,664
# 4       $250,000    $906,183
# ...          ...         ...
# 2689    $428,600    $-92,538
# 2690    $142,900    $-93,395
# 2691    $105,000   $-146,550
# 2692  $1,953,130   $-161,125
# 2693    $296,880   $-167,126
#
# [2694 rows x 8 columns]

# %% [markdown]
# ### Dropping the Rank column from the IPL data, since it doesn't contribute the target variable of preducting the IPL player value

# %%
ipl_full.drop(['Rank'],axis=1,inplace=True)

# %%
ipl_full
# Out:
#              Player                   Team  RAA   Wins  EFscore      Salary  \
# 0          SE Marsh        Kings XI Punjab  377  1.355    0.231         NaN
# 1         SR Watson       Rajasthan Royals  347  1.250    0.297    $125,000
# 2     Sohail Tanvir       Rajasthan Royals  294  1.059    0.194         NaN
# 3         G Gambhir       Delhi Daredevils  216  0.776    0.160    $725,000
# 4          GC Smith       Rajasthan Royals  202  0.725    0.139    $250,000
# ...             ...                    ...  ...    ...      ...         ...
# 2689      CJ Jordan         Mumbai Indians -195 -0.686    0.019    $428,600
# 2690       UT Yadav  Kolkata Knight Riders -195 -0.687    0.015    $142,900
# 2691      JO Holder       Rajasthan Royals -213 -0.749    0.026    $105,000
# 2692      SP Narine  Kolkata Knight Riders -218 -0.766    0.067  $1,953,130
# 2693      RD Chahar           Punjab Kings -219 -0.773    0.056    $296,880
#
#            Value
# 0     $1,270,355
# 1     $1,209,660
# 2     $1,099,252
# 3       $935,664
# 4       $906,183
# ...          ...
# 2689    $-92,538
# 2690    $-93,395
# 2691   $-146,550
# 2692   $-161,125
# 2693   $-167,126
#
# [2694 rows x 7 columns]

# %% [markdown]
# ### Checking the data types of all the features in the data

# %%
ipl_full.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2694 entries, 0 to 2693
# Data columns (total 7 columns):
#  #   Column   Non-Null Count  Dtype
# ---  ------   --------------  -----
#  0   Player   2694 non-null   object
#  1   Team     2694 non-null   object
#  2   RAA      2694 non-null   int64
#  3   Wins     2694 non-null   float64
#  4   EFscore  2694 non-null   float64
#  5   Salary   1924 non-null   object
#  6   Value    2694 non-null   object
# dtypes: float64(2), int64(1), object(4)
# memory usage: 147.5+ KB

# %% [markdown]
# ### Checking for the duplicated values in the data and remove if any

# %%
ipl_full[ipl_full.duplicated(keep= False)]
# Out:
# Empty DataFrame
# Columns: [Player, Team, RAA, Wins, EFscore, Salary, Value]
# Index: []

# %% [markdown]
# ### Checking for the null values in all the features of the data

# %%
ipl_full.isna().sum()
# Out:
# Player       0
# Team         0
# RAA          0
# Wins         0
# EFscore      0
# Salary     770
# Value        0
# dtype: int64

# %% [markdown]
# ### Import Visualisation libraries

# %%
import matplotlib.pyplot as plt
from wordcloud import WordCloud

# %% [markdown]
# ### Visualize the player with higher frequency in all these years, in the form of Word Cloud. The bigger the size of the words, the more number of times, it has occured in the data

# %%
player = ipl_full.Player
player = player.dropna()
text = player.explode().to_list()
wc = WordCloud(width=1500, height=1000).generate(' '.join(text))
plt.figure(figsize=(15,15))
plt.axis('off')
plt.imshow(wc)
plt.show()

# %% [markdown]
# ### Dropping the column Player and Team, since tehy do not add any value to the output player value

# %%
ipl_full=ipl_full.drop(["Player","Team"],axis=1)

# %% [markdown]
# ### Convert the salary column to float data type, since it is an object with the strings and characters

# %%
ipl_full['Salary'] = ipl_full['Salary'].str.replace(',', '').str.replace('$', '').astype(float)

# %% [markdown]
# ### Convert the value column to float data type, since it is an object with the strings and characters

# %%
ipl_full['Value'] = ipl_full['Value'].str.replace(',', '').str.replace('$', '').astype(float)

# %% [markdown]
# ### Convert the RAA column to float data type

# %%
ipl_full["RAA"]=ipl_full["RAA"].astype(float)

# %%
ipl_full
# Out:
#         RAA   Wins  EFscore     Salary      Value
# 0     377.0  1.355    0.231        NaN  1270355.0
# 1     347.0  1.250    0.297   125000.0  1209660.0
# 2     294.0  1.059    0.194        NaN  1099252.0
# 3     216.0  0.776    0.160   725000.0   935664.0
# 4     202.0  0.725    0.139   250000.0   906183.0
# ...     ...    ...      ...        ...        ...
# 2689 -195.0 -0.686    0.019   428600.0   -92538.0
# 2690 -195.0 -0.687    0.015   142900.0   -93395.0
# 2691 -213.0 -0.749    0.026   105000.0  -146550.0
# 2692 -218.0 -0.766    0.067  1953130.0  -161125.0
# 2693 -219.0 -0.773    0.056   296880.0  -167126.0
#
# [2694 rows x 5 columns]

# %% [markdown]
# ### Use seaborn  library for visualisation of the whether the data is normally distributed

# %%
import seaborn as sns

# %%
sns.pairplot(data=ipl_full)

# %% [markdown]
# ### Check the statistics of the data

# %%
ipl_full.describe()
# Out:
#                RAA         Wins      EFscore        Salary         Value
# count  2694.000000  2694.000000  2694.000000  1.924000e+03  2.694000e+03
# mean      0.012992     0.000046     0.057396  5.500035e+05  5.525099e+05
# std      93.997619     0.336334     0.051440  5.519717e+05  3.697290e+05
# min    -339.000000    -1.231000     0.000000  1.500000e+04 -8.798860e+05
# 25%     -53.000000    -0.190000     0.015000  1.287500e+05  3.627362e+05
# 50%     -14.500000    -0.051500     0.045000  4.000000e+05  5.027590e+05
# 75%      37.000000     0.133000     0.088000  7.500000e+05  6.817260e+05
# max     615.000000     2.041000     0.365000  3.000000e+06  2.742662e+06

# %% [markdown]
# ### Import Pycaret Library, that automatically fits teh data to different models and compares them based on many loss functions and accuracy

# %%
from pycaret.regression import *

# %% [markdown]
# ### Pass the data and target feature to the pycaret model and specify required features for tuning

# %%
reg = setup(data = ipl_full, 
            target = 'Value',
            normalize = True,
            session_id=123)

# %% [markdown]
# ### comparing the results of accuracy and loss functions of different models

# %%
compare_models()

# %% [markdown]
# ### Create a variable to save the parameters considered for teh catboost regressor, since it has a relatively high accuracy and low RMSe value

# %%
catboost = create_model('catboost')
# Out:
#
#
# Initiated  . . . . . . . . . . . . . . . . . .            13:05:28
# Status     . . . . . . . . . . . . . . . . . .    Fitting 10 Folds
# Estimator  . . . . . . . . . . . . . . . . . .  CatBoost Regressor
# <style type="text/css">
# #T_52433_row10_col0, #T_52433_row10_col1, #T_52433_row10_col2, #T_52433_row10_col3, #T_52433_row10_col4, #T_52433_row10_col5 {
#   background: yellow;
# }
# </style>
# <table id="T_52433">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_52433_level0_col0" class="col_heading level0 col0" >MAE</th>
#       <th id="T_52433_level0_col1" class="col_heading level0 col1" >MSE</th>
#       <th id="T_52433_level0_col2" class="col_heading level0 col2" >RMSE</th>
#       <th id="T_52433_level0_col3" class="col_heading level0 col3" >R2</th>
#       <th id="T_52433_level0_col4" class="col_heading level0 col4" >RMSLE</th>
#       <th id="T_52433_level0_col5" class="col_heading level0 col5" >MAPE</th>
#     </tr>
#     <tr>
#       <th class="index_name level0" >Fold</th>
#       <th class="blank col0" >&nbsp;</th>
#       <th class="blank col1" >&nbsp;</th>
#       <th class="blank col2" >&nbsp;</th>
#       <th class="blank col3" >&nbsp;</th>
#       <th class="blank col4" >&nbsp;</th>
#       <th class="blank col5" >&nbsp;</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_52433_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_52433_row0_col0" class="data row0 col0" >79286.1533</td>
#       <td id="T_52433_row0_col1" class="data row0 col1" >14759666991.3859</td>
#       <td id="T_52433_row0_col2" class="data row0 col2" >121489.3699</td>
#       <td id="T_52433_row0_col3" class="data row0 col3" >0.8998</td>
#       <td id="T_52433_row0_col4" class="data row0 col4" >0.6489</td>
#       <td id="T_52433_row0_col5" class="data row0 col5" >1.3461</td>
#     </tr>
#     <tr>
#       <th id="T_52433_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_52433_row1_col0" class="data row1 col0" >82039.6105</td>
#       <td id="T_52433_row1_col1" class="data row1 col1" >12585194828.7337</td>
#       <td id="T_52433_row1_col2" class="data row1 col2" >112183.7547</td>
#       <td id="T_52433_row1_col3" class="data row1 col3" >0.9187</td>
#       <td id="T_52433_row1_col4" class="data row1 col4" >0.3645</td>
#       <td id="T_52433_row1_col5" class="data row1 col5" >0.3187</td>
#     </tr>
#     <tr>
#       <th id="T_52433_level0_row2" class="row_heading level0 row2" >2</th>
#       <td id="T_52433_row2_col0" class="data row2 col0" >81211.5942</td>
#       <td id="T_52433_row2_col1" class="data row2 col1" >11104699791.9005</td>
#       <td id="T_52433_row2_col2" class="data row2 col2" >105378.8394</td>
#       <td id="T_52433_row2_col3" class="data row2 col3" >0.8933</td>
#       <td id="T_52433_row2_col4" class="data row2 col4" >0.5036</td>
#       <td id="T_52433_row2_col5" class="data row2 col5" >0.3196</td>
#     </tr>
#     <tr>
#       <th id="T_52433_level0_row3" class="row_heading level0 row3" >3</th>
#       <td id="T_52433_row3_col0" class="data row3 col0" >74231.9509</td>
#       <td id="T_52433_row3_col1" class="data row3 col1" >10700815489.4706</td>
#       <td id="T_52433_row3_col2" class="data row3 col2" >103444.7461</td>
#       <td id="T_52433_row3_col3" class="data row3 col3" >0.8924</td>
#       <td id="T_52433_row3_col4" class="data row3 col4" >0.3351</td>
#       <td id="T_52433_row3_col5" class="data row3 col5" >0.2742</td>
#     </tr>
#     <tr>
#       <th id="T_52433_level0_row4" class="row_heading level0 row4" >4</th>
#       <td id="T_52433_row4_col0" class="data row4 col0" >87327.6436</td>
#       <td id="T_52433_row4_col1" class="data row4 col1" >14220562796.5550</td>
#       <td id="T_52433_row4_col2" class="data row4 col2" >119250.0012</td>
#       <td id="T_52433_row4_col3" class="data row4 col3" >0.9102</td>
#       <td id="T_52433_row4_col4" class="data row4 col4" >0.3681</td>
#       <td id="T_52433_row4_col5" class="data row4 col5" >0.3154</td>
#     </tr>
#     <tr>
#       <th id="T_52433_level0_row5" class="row_heading level0 row5" >5</th>
#       <td id="T_52433_row5_col0" class="data row5 col0" >82402.7285</td>
#       <td id="T_52433_row5_col1" class="data row5 col1" >13741048120.2010</td>
#       <td id="T_52433_row5_col2" class="data row5 col2" >117222.2168</td>
#       <td id="T_52433_row5_col3" class="data row5 col3" >0.9046</td>
#       <td id="T_52433_row5_col4" class="data row5 col4" >0.4272</td>
#       <td id="T_52433_row5_col5" class="data row5 col5" >0.3293</td>
#     </tr>
#     <tr>
#       <th id="T_52433_level0_row6" class="row_heading level0 row6" >6</th>
#       <td id="T_52433_row6_col0" class="data row6 col0" >88513.9732</td>
#       <td id="T_52433_row6_col1" class="data row6 col1" >15906762534.3558</td>
#       <td id="T_52433_row6_col2" class="data row6 col2" >126122.0145</td>
#       <td id="T_52433_row6_col3" class="data row6 col3" >0.8701</td>
#       <td id="T_52433_row6_col4" class="data row6 col4" >0.3025</td>
#       <td id="T_52433_row6_col5" class="data row6 col5" >0.2880</td>
#     </tr>
#     <tr>
#       <th id="T_52433_level0_row7" class="row_heading level0 row7" >7</th>
#       <td id="T_52433_row7_col0" class="data row7 col0" >91393.8241</td>
#       <td id="T_52433_row7_col1" class="data row7 col1" >15804728180.3160</td>
#       <td id="T_52433_row7_col2" class="data row7 col2" >125716.8572</td>
#       <td id="T_52433_row7_col3" class="data row7 col3" >0.8955</td>
#       <td id="T_52433_row7_col4" class="data row7 col4" >0.3734</td>
#       <td id="T_52433_row7_col5" class="data row7 col5" >0.2431</td>
#     </tr>
#     <tr>
#       <th id="T_52433_level0_row8" class="row_heading level0 row8" >8</th>
#       <td id="T_52433_row8_col0" class="data row8 col0" >83174.1787</td>
#       <td id="T_52433_row8_col1" class="data row8 col1" >12879499069.9596</td>
#       <td id="T_52433_row8_col2" class="data row8 col2" >113487.8807</td>
#       <td id="T_52433_row8_col3" class="data row8 col3" >0.9112</td>
#       <td id="T_52433_row8_col4" class="data row8 col4" >0.4742</td>
#       <td id="T_52433_row8_col5" class="data row8 col5" >0.2578</td>
#     </tr>
#     <tr>
#       <th id="T_52433_level0_row9" class="row_heading level0 row9" >9</th>
#       <td id="T_52433_row9_col0" class="data row9 col0" >85849.7047</td>
#       <td id="T_52433_row9_col1" class="data row9 col1" >15760437056.2626</td>
#       <td id="T_52433_row9_col2" class="data row9 col2" >125540.5793</td>
#       <td id="T_52433_row9_col3" class="data row9 col3" >0.8789</td>
#       <td id="T_52433_row9_col4" class="data row9 col4" >0.5647</td>
#       <td id="T_52433_row9_col5" class="data row9 col5" >0.2798</td>
#     </tr>
#     <tr>
#       <th id="T_52433_level0_row10" class="row_heading level0 row10" >Mean</th>
#       <td id="T_52433_row10_col0" class="data row10 col0" >83543.1362</td>
#       <td id="T_52433_row10_col1" class="data row10 col1" >13746341485.9141</td>
#       <td id="T_52433_row10_col2" class="data row10 col2" >116983.6260</td>
#       <td id="T_52433_row10_col3" class="data row10 col3" >0.8975</td>
#       <td id="T_52433_row10_col4" class="data row10 col4" >0.4362</td>
#       <td id="T_52433_row10_col5" class="data row10 col5" >0.3972</td>
#     </tr>
#     <tr>
#       <th id="T_52433_level0_row11" class="row_heading level0 row11" >Std</th>
#       <td id="T_52433_row11_col0" class="data row11 col0" >4689.7621</td>
#       <td id="T_52433_row11_col1" class="data row11 col1" >1804601758.7298</td>
#       <td id="T_52433_row11_col2" class="data row11 col2" >7821.3002</td>
#       <td id="T_52433_row11_col3" class="data row11 col3" >0.0141</td>
#       <td id="T_52433_row11_col4" class="data row11 col4" >0.1047</td>
#       <td id="T_52433_row11_col5" class="data row11 col5" >0.3175</td>
#     </tr>
#   </tbody>
# </table>

# %% [markdown]
# ### Fetching the parameters of the catboost regressor

# %%
catboost.get_params()
# Out:
# {'loss_function': 'RMSE',
#  'border_count': 254,
#  'verbose': False,
#  'task_type': 'CPU',
#  'random_state': 123}

# %% [markdown]
# ### Hyper parameter tuning for the catboost regressor model

# %%
catboost_tune=tune_model(catboost)
# Out:
#
#
# Initiated  . . . . . . . . . . . . . . . . . .              13:05:44
# Status     . . . . . . . . . . . . . . . . . .  Loading Dependencies
# Estimator  . . . . . . . . . . . . . . . . . .    CatBoost Regressor
# <style type="text/css">
# #T_822b9_row10_col0, #T_822b9_row10_col1, #T_822b9_row10_col2, #T_822b9_row10_col3, #T_822b9_row10_col4, #T_822b9_row10_col5 {
#   background: yellow;
# }
# </style>
# <table id="T_822b9">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_822b9_level0_col0" class="col_heading level0 col0" >MAE</th>
#       <th id="T_822b9_level0_col1" class="col_heading level0 col1" >MSE</th>
#       <th id="T_822b9_level0_col2" class="col_heading level0 col2" >RMSE</th>
#       <th id="T_822b9_level0_col3" class="col_heading level0 col3" >R2</th>
#       <th id="T_822b9_level0_col4" class="col_heading level0 col4" >RMSLE</th>
#       <th id="T_822b9_level0_col5" class="col_heading level0 col5" >MAPE</th>
#     </tr>
#     <tr>
#       <th class="index_name level0" >Fold</th>
#       <th class="blank col0" >&nbsp;</th>
#       <th class="blank col1" >&nbsp;</th>
#       <th class="blank col2" >&nbsp;</th>
#       <th class="blank col3" >&nbsp;</th>
#       <th class="blank col4" >&nbsp;</th>
#       <th class="blank col5" >&nbsp;</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_822b9_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_822b9_row0_col0" class="data row0 col0" >79919.8303</td>
#       <td id="T_822b9_row0_col1" class="data row0 col1" >13601075665.7587</td>
#       <td id="T_822b9_row0_col2" class="data row0 col2" >116623.6497</td>
#       <td id="T_822b9_row0_col3" class="data row0 col3" >0.9077</td>
#       <td id="T_822b9_row0_col4" class="data row0 col4" >0.7348</td>
#       <td id="T_822b9_row0_col5" class="data row0 col5" >1.4443</td>
#     </tr>
#     <tr>
#       <th id="T_822b9_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_822b9_row1_col0" class="data row1 col0" >80840.6068</td>
#       <td id="T_822b9_row1_col1" class="data row1 col1" >12345616698.9746</td>
#       <td id="T_822b9_row1_col2" class="data row1 col2" >111110.8307</td>
#       <td id="T_822b9_row1_col3" class="data row1 col3" >0.9203</td>
#       <td id="T_822b9_row1_col4" class="data row1 col4" >0.5331</td>
#       <td id="T_822b9_row1_col5" class="data row1 col5" >0.3373</td>
#     </tr>
#     <tr>
#       <th id="T_822b9_level0_row2" class="row_heading level0 row2" >2</th>
#       <td id="T_822b9_row2_col0" class="data row2 col0" >85154.0098</td>
#       <td id="T_822b9_row2_col1" class="data row2 col1" >12138916874.9602</td>
#       <td id="T_822b9_row2_col2" class="data row2 col2" >110176.7529</td>
#       <td id="T_822b9_row2_col3" class="data row2 col3" >0.8834</td>
#       <td id="T_822b9_row2_col4" class="data row2 col4" >0.5416</td>
#       <td id="T_822b9_row2_col5" class="data row2 col5" >0.4079</td>
#     </tr>
#     <tr>
#       <th id="T_822b9_level0_row3" class="row_heading level0 row3" >3</th>
#       <td id="T_822b9_row3_col0" class="data row3 col0" >78333.2319</td>
#       <td id="T_822b9_row3_col1" class="data row3 col1" >10862224194.2462</td>
#       <td id="T_822b9_row3_col2" class="data row3 col2" >104221.9948</td>
#       <td id="T_822b9_row3_col3" class="data row3 col3" >0.8907</td>
#       <td id="T_822b9_row3_col4" class="data row3 col4" >0.4658</td>
#       <td id="T_822b9_row3_col5" class="data row3 col5" >0.7187</td>
#     </tr>
#     <tr>
#       <th id="T_822b9_level0_row4" class="row_heading level0 row4" >4</th>
#       <td id="T_822b9_row4_col0" class="data row4 col0" >95059.0388</td>
#       <td id="T_822b9_row4_col1" class="data row4 col1" >15104541732.4744</td>
#       <td id="T_822b9_row4_col2" class="data row4 col2" >122900.5359</td>
#       <td id="T_822b9_row4_col3" class="data row4 col3" >0.9046</td>
#       <td id="T_822b9_row4_col4" class="data row4 col4" >0.4108</td>
#       <td id="T_822b9_row4_col5" class="data row4 col5" >0.4155</td>
#     </tr>
#     <tr>
#       <th id="T_822b9_level0_row5" class="row_heading level0 row5" >5</th>
#       <td id="T_822b9_row5_col0" class="data row5 col0" >88166.8150</td>
#       <td id="T_822b9_row5_col1" class="data row5 col1" >14618228773.5128</td>
#       <td id="T_822b9_row5_col2" class="data row5 col2" >120905.8674</td>
#       <td id="T_822b9_row5_col3" class="data row5 col3" >0.8986</td>
#       <td id="T_822b9_row5_col4" class="data row5 col4" >0.4629</td>
#       <td id="T_822b9_row5_col5" class="data row5 col5" >0.3568</td>
#     </tr>
#     <tr>
#       <th id="T_822b9_level0_row6" class="row_heading level0 row6" >6</th>
#       <td id="T_822b9_row6_col0" class="data row6 col0" >86887.5963</td>
#       <td id="T_822b9_row6_col1" class="data row6 col1" >14978858793.7086</td>
#       <td id="T_822b9_row6_col2" class="data row6 col2" >122388.1481</td>
#       <td id="T_822b9_row6_col3" class="data row6 col3" >0.8777</td>
#       <td id="T_822b9_row6_col4" class="data row6 col4" >0.3572</td>
#       <td id="T_822b9_row6_col5" class="data row6 col5" >0.3059</td>
#     </tr>
#     <tr>
#       <th id="T_822b9_level0_row7" class="row_heading level0 row7" >7</th>
#       <td id="T_822b9_row7_col0" class="data row7 col0" >89647.3966</td>
#       <td id="T_822b9_row7_col1" class="data row7 col1" >14384469831.9361</td>
#       <td id="T_822b9_row7_col2" class="data row7 col2" >119935.2735</td>
#       <td id="T_822b9_row7_col3" class="data row7 col3" >0.9049</td>
#       <td id="T_822b9_row7_col4" class="data row7 col4" >0.3065</td>
#       <td id="T_822b9_row7_col5" class="data row7 col5" >0.2408</td>
#     </tr>
#     <tr>
#       <th id="T_822b9_level0_row8" class="row_heading level0 row8" >8</th>
#       <td id="T_822b9_row8_col0" class="data row8 col0" >85758.5987</td>
#       <td id="T_822b9_row8_col1" class="data row8 col1" >12957512545.9916</td>
#       <td id="T_822b9_row8_col2" class="data row8 col2" >113831.0702</td>
#       <td id="T_822b9_row8_col3" class="data row8 col3" >0.9107</td>
#       <td id="T_822b9_row8_col4" class="data row8 col4" >0.7264</td>
#       <td id="T_822b9_row8_col5" class="data row8 col5" >0.3134</td>
#     </tr>
#     <tr>
#       <th id="T_822b9_level0_row9" class="row_heading level0 row9" >9</th>
#       <td id="T_822b9_row9_col0" class="data row9 col0" >87563.0770</td>
#       <td id="T_822b9_row9_col1" class="data row9 col1" >15777731632.8312</td>
#       <td id="T_822b9_row9_col2" class="data row9 col2" >125609.4409</td>
#       <td id="T_822b9_row9_col3" class="data row9 col3" >0.8788</td>
#       <td id="T_822b9_row9_col4" class="data row9 col4" >0.4697</td>
#       <td id="T_822b9_row9_col5" class="data row9 col5" >0.3306</td>
#     </tr>
#     <tr>
#       <th id="T_822b9_level0_row10" class="row_heading level0 row10" >Mean</th>
#       <td id="T_822b9_row10_col0" class="data row10 col0" >85733.0201</td>
#       <td id="T_822b9_row10_col1" class="data row10 col1" >13676917674.4394</td>
#       <td id="T_822b9_row10_col2" class="data row10 col2" >116770.3564</td>
#       <td id="T_822b9_row10_col3" class="data row10 col3" >0.8977</td>
#       <td id="T_822b9_row10_col4" class="data row10 col4" >0.5009</td>
#       <td id="T_822b9_row10_col5" class="data row10 col5" >0.4871</td>
#     </tr>
#     <tr>
#       <th id="T_822b9_level0_row11" class="row_heading level0 row11" >Std</th>
#       <td id="T_822b9_row11_col0" class="data row11 col0" >4751.0434</td>
#       <td id="T_822b9_row11_col1" class="data row11 col1" >1487174533.8308</td>
#       <td id="T_822b9_row11_col2" class="data row11 col2" >6449.9255</td>
#       <td id="T_822b9_row11_col3" class="data row11 col3" >0.0137</td>
#       <td id="T_822b9_row11_col4" class="data row11 col4" >0.1336</td>
#       <td id="T_822b9_row11_col5" class="data row11 col5" >0.3419</td>
#     </tr>
#   </tbody>
# </table>
# Fitting 10 folds for each of 10 candidates, totalling 100 fits

# %%
print(catboost_tune)
# Out:
# <catboost.core.CatBoostRegressor object at 0x00000212ACD5F9D0>

# %% [markdown]
# ### Evaluating the cat boost model

# %%
evaluate_model(catboost_tune)
# Out:
# interactive(children=(ToggleButtons(description='Plot Type:', icons=('',), options=(('Pipeline Plot', 'pipelin…

# %% [markdown]
# ### Use the model to predict the IPL Player value and check the error values

# %%
predict_model(catboost_tune);
# Out:
# <style type="text/css">
# </style>
# <table id="T_90be0">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_90be0_level0_col0" class="col_heading level0 col0" >Model</th>
#       <th id="T_90be0_level0_col1" class="col_heading level0 col1" >MAE</th>
#       <th id="T_90be0_level0_col2" class="col_heading level0 col2" >MSE</th>
#       <th id="T_90be0_level0_col3" class="col_heading level0 col3" >RMSE</th>
#       <th id="T_90be0_level0_col4" class="col_heading level0 col4" >R2</th>
#       <th id="T_90be0_level0_col5" class="col_heading level0 col5" >RMSLE</th>
#       <th id="T_90be0_level0_col6" class="col_heading level0 col6" >MAPE</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_90be0_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_90be0_row0_col0" class="data row0 col0" >CatBoost Regressor</td>
#       <td id="T_90be0_row0_col1" class="data row0 col1" >86376.0986</td>
#       <td id="T_90be0_row0_col2" class="data row0 col2" >14914589114.7421</td>
#       <td id="T_90be0_row0_col3" class="data row0 col3" >122125.3009</td>
#       <td id="T_90be0_row0_col4" class="data row0 col4" >0.8917</td>
#       <td id="T_90be0_row0_col5" class="data row0 col5" >0.4035</td>
#       <td id="T_90be0_row0_col6" class="data row0 col6" >0.2544</td>
#     </tr>
#   </tbody>
# </table>

# %% [markdown]
# ### Finalise the catboost model

# %%
final_catboost = finalize_model(catboost_tune)

# %% [markdown]
# ### Importing the pickle file, in order to use it during deployment of the model

# %%
import pickle

# %% [markdown]
# ### Dump the created final cat boost mmodel to the pickle file

# %%
pickle.dump(final_catboost,open('ipl.pkl','wb'))
