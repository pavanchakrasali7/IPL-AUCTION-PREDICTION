# %% [markdown]
# # <center>Predict IPL Player Value

# %% [markdown]
# ### Importing Libraries

# %%
import pandas as pd
import warnings
warnings.simplefilter(action='ignore')

# %% [markdown]
# ### Reading the IPL data of the year 2008

# %%
ipl_08=pd.read_csv("C:\\Users\\pavan\\OneDrive\\Desktop\\final project\\Ipl Data\\2008.csv")
ipl_08.head()
# Out:
#    Rank         Player              Team  RAA   Wins  EFscore    Salary  \
# 0     1       SE Marsh   Kings XI Punjab  377  1.355    0.231       NaN
# 1     2      SR Watson  Rajasthan Royals  347  1.250    0.297  $125,000
# 2     3  Sohail Tanvir  Rajasthan Royals  294  1.059    0.194       NaN
# 3     4      G Gambhir  Delhi Daredevils  216  0.776    0.160  $725,000
# 4     5       GC Smith  Rajasthan Royals  202  0.725    0.139  $250,000
#
#         Value
# 0  $1,270,355
# 1  $1,209,660
# 2  $1,099,252
# 3    $935,664
# 4    $906,183

# %% [markdown]
# ### Reading the IPL data of the year 2009

# %%
ipl_09=pd.read_csv("C:\\Users\\pavan\\OneDrive\\Desktop\\final project\\Ipl Data\\2009.csv")
ipl_09.head()
# Out:
#    Rank          Player                   Team  RAA   Wins  EFscore    Salary  \
# 0     1       ML Hayden    Chennai Super Kings  338  1.366    0.238  $375,000
# 1     2  AB de Villiers       Delhi Daredevils  256  1.037    0.195  $300,000
# 2     3       JP Duminy         Mumbai Indians  191  0.775    0.177  $950,000
# 3     4        BJ Hodge  Kolkata Knight Riders  189  0.766    0.196       NaN
# 4     5       RG Sharma        Deccan Chargers  156  0.630    0.174  $750,000
#
#         Value
# 0  $1,331,596
# 1  $1,145,098
# 2    $996,579
# 3    $991,477
# 4    $914,384

# %% [markdown]
# ### Reading the IPL data of the year 2010

# %%
ipl_10=pd.read_csv("C:\\Users\\pavan\\OneDrive\\Desktop\\final project\\Ipl Data\\2010.csv")
ipl_10.head()
# Out:
#    Rank            Player                         Team  RAA   Wins  EFscore  \
# 0     1      SR Tendulkar               Mumbai Indians  268  0.948    0.205
# 1     2          SK Raina          Chennai Super Kings  239  0.845    0.223
# 2     3  DPMD Jayawardene              Kings XI Punjab  195  0.691    0.146
# 3     4      KP Pietersen  Royal Challengers Bangalore  160  0.566    0.126
# 4     5         JH Kallis  Royal Challengers Bangalore  157  0.556    0.268
#
#        Salary       Value
# 0         NaN  $1,047,446
# 1    $650,000    $990,667
# 2    $475,000    $905,775
# 3  $1,550,000    $836,869
# 4    $900,000    $831,356

# %% [markdown]
# ### Reading the IPL data of the year 2011

# %%
ipl_11=pd.read_csv("C:\\Users\\pavan\\OneDrive\\Desktop\\final project\\Ipl Data\\2011.csv")
ipl_11.head()
# Out:
#    Rank        Player                         Team  RAA   Wins  EFscore  \
# 0     1      CH Gayle  Royal Challengers Bangalore  351  1.303    0.239
# 1     2    SL Malinga               Mumbai Indians  325  1.207    0.207
# 2     3   S Badrinath          Chennai Super Kings  267  0.990    0.160
# 3     4      SE Marsh              Kings XI Punjab  246  0.912    0.149
# 4     5  SR Tendulkar               Mumbai Indians  217  0.807    0.166
#
#      Salary       Value
# 0  $650,000  $1,674,414
# 1       NaN  $1,592,801
# 2  $800,000  $1,408,322
# 3  $400,000  $1,342,011
# 4       NaN  $1,252,747

# %% [markdown]
# ### Reading the IPL data of the year 2012

# %%
ipl_12=pd.read_csv("C:\\Users\\pavan\\OneDrive\\Desktop\\final project\\Ipl Data\\2012.csv")
ipl_12.head()
# Out:
#    Rank     Player                         Team  RAA   Wins  EFscore  \
# 0     1   CH Gayle  Royal Challengers Bangalore  354  1.286    0.212
# 1     2   S Dhawan              Deccan Chargers  304  1.103    0.208
# 2     3  SP Narine        Kolkata Knight Riders  298  1.082    0.187
# 3     4  G Gambhir        Kolkata Knight Riders  221  0.804    0.148
# 4     5  AM Rahane             Rajasthan Royals  217  0.787    0.156
#
#        Salary       Value
# 0    $650,000  $1,644,515
# 1    $300,000  $1,500,824
# 2    $700,000  $1,484,335
# 3  $2,400,000  $1,266,050
# 4         NaN  $1,252,702

# %% [markdown]
# ### Reading the IPL data of the year 2013

# %%
ipl_13=pd.read_csv("C:\\Users\\pavan\\OneDrive\\Desktop\\final project\\Ipl Data\\2013.csv")
ipl_13.head()
# Out:
#    Rank      Player                         Team  RAA   Wins  EFscore  \
# 0     1    CH Gayle  Royal Challengers Bangalore  447  1.729    0.210
# 1     2  MEK Hussey          Chennai Super Kings  414  1.602    0.224
# 2     3     V Kohli  Royal Challengers Bangalore  339  1.311    0.179
# 3     4    DJ Bravo          Chennai Super Kings  258  1.001    0.218
# 4     5    SK Raina          Chennai Super Kings  253  0.981    0.143
#
#        Salary       Value
# 0  $2,000,000  $2,554,267
# 1    $425,000  $2,419,187
# 2  $1,800,000  $2,109,674
# 3    $200,000  $1,779,953
# 4  $1,300,000  $1,758,680

# %% [markdown]
# ### Reading the IPL data of the year 2014

# %%
ipl_14=pd.read_csv("C:\\Users\\pavan\\OneDrive\\Desktop\\final project\\Ipl Data\\2014.csv")
ipl_14.head()
# Out:
#    Rank      Player                         Team  RAA   Wins  EFscore  \
# 0     1  RV Uthappa        Kolkata Knight Riders  285  0.968    0.210
# 1     2    MS Dhoni          Chennai Super Kings  229  0.779    0.143
# 2     3   DA Warner          Sunrisers Hyderabad  218  0.742    0.167
# 3     4  SL Malinga               Mumbai Indians  209  0.711    0.152
# 4     5    VR Aaron  Royal Challengers Bangalore  208  0.707    0.175
#
#        Salary       Value
# 0    $833,000  $1,696,711
# 1  $2,083,333  $1,466,583
# 2    $916,000  $1,421,532
# 3  $1,350,000  $1,383,786
# 4    $333,000  $1,378,916

# %% [markdown]
# ### Reading the IPL data of the year 2015

# %%
ipl_15=pd.read_csv("C:\\Users\\pavan\\OneDrive\\Desktop\\final project\\Ipl Data\\2015.csv")
ipl_15.head()
# Out:
#    Rank          Player                         Team  RAA   Wins  EFscore  \
# 0     1  AB de Villiers  Royal Challengers Bangalore  300  1.080    0.188
# 1     2       AM Rahane             Rajasthan Royals  274  0.986    0.180
# 2     3        DJ Bravo          Chennai Super Kings  251  0.901    0.227
# 3     4       DA Warner          Sunrisers Hyderabad  243  0.874    0.172
# 4     5    MC Henriques          Sunrisers Hyderabad  242  0.871    0.201
#
#        Salary       Value
# 0  $1,583,333  $1,689,095
# 1  $1,333,333  $1,585,393
# 2    $666,667  $1,491,620
# 3    $916,000  $1,461,833
# 4    $166,000  $1,458,524

# %% [markdown]
# ### Reading the IPL data of the year 2016

# %%
ipl_16=pd.read_csv("C:\\Users\\pavan\\OneDrive\\Desktop\\final project\\Ipl Data\\2016.csv")
ipl_16.head()
# Out:
#    Rank          Player                         Team  RAA   Wins  EFscore  \
# 0     1         V Kohli  Royal Challengers Bangalore  615  2.041    0.365
# 1     2       DA Warner          Sunrisers Hyderabad  414  1.375    0.237
# 2     3  AB de Villiers  Royal Challengers Bangalore  307  1.019    0.189
# 3     4       YS Chahal  Royal Challengers Bangalore  251  0.833    0.155
# 4     5       G Gambhir        Kolkata Knight Riders  241  0.799    0.147
#
#        Salary       Value
# 0  $2,500,000  $2,594,886
# 1    $916,000  $1,890,050
# 2  $1,583,333  $1,513,292
# 3     $16,000  $1,316,446
# 4  $1,666,667  $1,280,463

# %% [markdown]
# ### Reading the IPL data of the year 2017

# %%
ipl_17=pd.read_csv("C:\\Users\\pavan\\OneDrive\\Desktop\\final project\\Ipl Data\\2017.csv")
ipl_17.head()
# Out:
#    Rank      Player                     Team  RAA   Wins  EFscore    Salary  \
# 0     1   DA Warner      Sunrisers Hyderabad  351  1.274    0.211  $916,000
# 1     2  JD Unadkat  Rising Pune Supergiants  316  1.146    0.207   $45,000
# 2     3     B Kumar      Sunrisers Hyderabad  304  1.104    0.228  $708,000
# 3     4     HM Amla          Kings XI Punjab  236  0.854    0.151       NaN
# 4     5      AJ Tye            Gujarat Lions  205  0.742    0.132   $75,000
#
#         Value
# 0  $1,783,802
# 1  $1,648,517
# 2  $1,604,126
# 3  $1,339,898
# 4  $1,221,524

# %% [markdown]
# ### Reading the IPL data of the year 2018

# %%
ipl_18=pd.read_csv("C:\\Users\\pavan\\OneDrive\\Desktop\\final project\\Ipl Data\\2018.csv")
ipl_18.head()
# Out:
#    Rank         Player                 Team  RAA   Wins  EFscore      Salary  \
# 0     1  KS Williamson  Sunrisers Hyderabad  351  1.221    0.214    $468,750
# 1     2       KL Rahul      Kings XI Punjab  328  1.141    0.193  $1,718,750
# 2     3      AT Rayudu  Chennai Super Kings  327  1.137    0.198    $343,750
# 3     4        RR Pant     Delhi Daredevils  322  1.122    0.201  $2,343,750
# 4     5       MS Dhoni  Chennai Super Kings  290  1.011    0.167  $2,343,750
#
#         Value
# 0  $2,397,239
# 1  $2,280,549
# 2  $2,274,714
# 3  $2,252,835
# 4  $2,090,927

# %% [markdown]
# ### Reading the IPL data of the year 2019

# %%
ipl_19=pd.read_csv("C:\\Users\\pavan\\OneDrive\\Desktop\\final project\\Ipl Data\\2019.csv")
ipl_19.head()
# Out:
#    Rank       Player                   Team  RAA   Wins  EFscore      Salary  \
# 0     1    DA Warner    Sunrisers Hyderabad  410  1.414    0.224  $1,953,130
# 1     2   AD Russell  Kolkata Knight Riders  307  1.060    0.242  $1,328,130
# 2     3     MS Dhoni    Chennai Super Kings  305  1.053    0.176  $2,343,750
# 3     4  Imran Tahir    Chennai Super Kings  295  1.018    0.200    $156,250
# 4     5     KL Rahul        Kings XI Punjab  288  0.994    0.217  $1,718,750
#
#         Value
# 0  $2,742,662
# 1  $2,200,658
# 2  $2,189,940
# 3  $2,136,352
# 4  $2,099,606

# %% [markdown]
# ### Reading the IPL data of the year 2020

# %%
ipl_20=pd.read_csv("C:\\Users\\pavan\\OneDrive\\Desktop\\final project\\Ipl Data\\2020.csv")
ipl_20.head()
# Out:
#    Rank        Player             Team  RAA   Wins  EFscore      Salary  \
# 0     1     JJ Bumrah   Mumbai Indians  379  1.281    0.238  $1,093,750
# 1     2      KL Rahul  Kings XI Punjab  330  1.113    0.194  $1,718,750
# 2     3      K Rabada   Delhi Capitals  320  1.082    0.232    $656,250
# 3     4  Ishan Kishan   Mumbai Indians  261  0.881    0.157    $968,750
# 4     5      S Dhawan   Delhi Capitals  249  0.842    0.168    $812,500
#
#         Value
# 0  $2,448,655
# 1  $2,204,319
# 2  $2,159,233
# 3  $1,866,902
# 4  $1,810,181

# %% [markdown]
# ### Reading the IPL data of the year 2021

# %%
ipl_21=pd.read_csv("C:\\Users\\pavan\\OneDrive\\Desktop\\final project\\Ipl Data\\2021.csv")
ipl_21.head()
# Out:
#    Rank        Player                         Team  RAA   Wins  EFscore  \
# 0     1      KL Rahul                 Punjab Kings  222  0.783    0.248
# 1     2      HV Patel  Royal Challengers Bangalore  196  0.692    0.238
# 2     3      S Dhawan               Delhi Capitals  190  0.669    0.215
# 3     4  F du Plessis          Chennai Super Kings  184  0.649    0.177
# 4     5     CH Morris             Rajasthan Royals  159  0.560    0.219
#
#        Salary       Value
# 0  $1,718,750  $1,757,372
# 1     $31,250  $1,629,608
# 2    $812,500  $1,597,316
# 3    $250,000  $1,569,236
# 4  $2,321,400  $1,444,279

# %% [markdown]
# ### Reading the IPL data of the year 2022

# %%
ipl_22=pd.read_csv("C:\\Users\\pavan\\OneDrive\\Desktop\\final project\\Ipl Data\\2022.csv")
ipl_22.head()
# Out:
#    Rank      Player                   Team  RAA   Wins  EFscore      Salary  \
# 0     1  JC Buttler       Rajasthan Royals  501  1.850    0.263    $687,500
# 1     2    KL Rahul   Lucknow Super Giants  332  1.224    0.173  $1,718,750
# 2     3   DA Miller         Gujarat Titans  300  1.108    0.162    $107,100
# 3     4  AD Russell  Kolkata Knight Riders  275  1.015    0.194  $1,328,130
# 4     5   HH Pandya         Gujarat Titans  245  0.905    0.179  $1,718,750
#
#         Value
# 0  $2,360,510
# 1  $1,737,300
# 2  $1,621,817
# 3  $1,529,231
# 4  $1,419,722

# %% [markdown]
# ### Reading the IPL data of the year 2023

# %%
ipl_23=pd.read_csv("C:\\Users\\pavan\\OneDrive\\Desktop\\final project\\Ipl Data\\2023.csv")
ipl_23.head()
# Out:
#    Rank        Player                         Team  RAA   Wins  EFscore  \
# 0     1  Shubman Gill               Gujarat Titans  484  1.703    0.253
# 1     2  F du Plessis  Royal Challengers Bangalore  405  1.426    0.200
# 2     3     MM Sharma               Gujarat Titans  373  1.315    0.192
# 3     4     DP Conway          Chennai Super Kings  320  1.126    0.166
# 4     5       V Kohli  Royal Challengers Bangalore  314  1.105    0.166
#
#        Salary       Value
# 0    $281,250  $1,955,647
# 1    $250,000  $1,718,164
# 2     $71,400  $1,622,999
# 3         NaN  $1,460,962
# 4  $2,656,250  $1,442,958

# %% [markdown]
# ### Concatinating the IPL data of all the years from teh year 2008 to 2023, and considering it the training data to predict the value of the player

# %%
ipl_full = pd.concat([ipl_08,ipl_09,ipl_10,ipl_11,ipl_12,ipl_13,ipl_14,ipl_15,ipl_16,ipl_17,ipl_18,ipl_19,ipl_20,ipl_21,ipl_22,ipl_23], ignore_index=True)

# %%
# ipl_full=pd.read_csv("C:\\Users\\pavan\\OneDrive\\Desktop\\final project - Copy\\Ipl Data\\combined.csv")

# %% [markdown]
# ### Dropping the Rank column from the IPL data, since it doesn't contribute the target variable of preducting the IPL player value

# %%
ipl_full.drop(['Rank'],axis=1,inplace=True)

# %%
ipl_full
# Out:
#               Player                         Team  RAA   Wins  EFscore  \
# 0     A Ashish Reddy          Sunrisers Hyderabad   51  0.182    0.039
# 1     A Ashish Reddy          Sunrisers Hyderabad    8  0.027    0.020
# 2     A Ashish Reddy              Deccan Chargers   -9 -0.033    0.069
# 3     A Ashish Reddy          Sunrisers Hyderabad  -36 -0.139    0.038
# 4           A Badoni         Lucknow Super Giants   21  0.076    0.054
# ...              ...                          ...  ...    ...      ...
# 2688          Z Khan  Royal Challengers Bangalore  -42 -0.151    0.107
# 2689          Z Khan             Delhi Daredevils  -67 -0.243    0.066
# 2690          Z Khan  Royal Challengers Bangalore  -34 -0.123    0.109
# 2691          Z Khan             Delhi Daredevils  -87 -0.288    0.076
# 2692          Z Khan  Royal Challengers Bangalore -101 -0.375    0.102
#
#         Salary     Value
# 0      $33,000  $698,411
# 1      $33,000  $463,447
# 2          NaN  $608,840
# 3          NaN  $567,428
# 4          NaN  $594,416
# ...        ...       ...
# 2688  $450,000  $399,811
# 2689  $666,667  $180,463
# 2690  $900,000  $538,172
# 2691  $666,667  $130,079
# 2692  $900,000  $247,887
#
# [2693 rows x 7 columns]

# %% [markdown]
# ### Checking the data types of all the features in the data

# %%
ipl_full.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2693 entries, 0 to 2692
# Data columns (total 7 columns):
#  #   Column   Non-Null Count  Dtype
# ---  ------   --------------  -----
#  0   Player   2693 non-null   object
#  1   Team     2693 non-null   object
#  2   RAA      2693 non-null   int64
#  3   Wins     2693 non-null   float64
#  4   EFscore  2693 non-null   float64
#  5   Salary   1925 non-null   object
#  6   Value    2693 non-null   object
# dtypes: float64(2), int64(1), object(4)
# memory usage: 147.4+ KB

# %% [markdown]
# ### Checking for the duplicated values in the data and remove if any

# %%
ipl_full[ipl_full.duplicated(keep= False)]
# Out:
# Empty DataFrame
# Columns: [Player, Team, RAA, Wins, EFscore, Salary, Value]
# Index: []

# %% [markdown]
# ### Checking for the null values in all the features of the data

# %%
ipl_full.isna().sum()
# Out:
# Player       0
# Team         0
# RAA          0
# Wins         0
# EFscore      0
# Salary     768
# Value        0
# dtype: int64

# %% [markdown]
# ### Import Visualisation libraries

# %%
import matplotlib.pyplot as plt
from wordcloud import WordCloud

# %% [markdown]
# ### Visualize the player with higher frequency in all these years, in the form of Word Cloud. The bigger the size of the words, the more number of times, it has occured in the data

# %%
player = ipl_full.Player
player = player.dropna()
text = player.explode().to_list()
wc = WordCloud(width=1500, height=1000).generate(' '.join(text))
plt.figure(figsize=(15,15))
plt.axis('off')
plt.imshow(wc)
plt.show()

# %% [markdown]
# ### Dropping the column Player and Team, since tehy do not add any value to the output player value

# %%
ipl_full=ipl_full.drop(["Player","Team"],axis=1)

# %% [markdown]
# ### Convert the salary column to float data type, since it is an object with the strings and characters

# %%
ipl_full['Salary'] = ipl_full['Salary'].str.replace(',', '').str.replace('$', '').astype(float)

# %% [markdown]
# ### Convert the value column to float data type, since it is an object with the strings and characters

# %%
ipl_full['Value'] = ipl_full['Value'].str.replace(',', '').str.replace('$', '').astype(float)

# %% [markdown]
# ### Convert the RAA column to float data type

# %%
ipl_full["RAA"]=ipl_full["RAA"].astype(float)

# %%
ipl_full
# Out:
#         RAA   Wins  EFscore    Salary     Value
# 0      51.0  0.182    0.039   33000.0  698411.0
# 1       8.0  0.027    0.020   33000.0  463447.0
# 2      -9.0 -0.033    0.069       NaN  608840.0
# 3     -36.0 -0.139    0.038       NaN  567428.0
# 4      21.0  0.076    0.054       NaN  594416.0
# ...     ...    ...      ...       ...       ...
# 2688  -42.0 -0.151    0.107  450000.0  399811.0
# 2689  -67.0 -0.243    0.066  666667.0  180463.0
# 2690  -34.0 -0.123    0.109  900000.0  538172.0
# 2691  -87.0 -0.288    0.076  666667.0  130079.0
# 2692 -101.0 -0.375    0.102  900000.0  247887.0
#
# [2693 rows x 5 columns]

# %% [markdown]
# ### Use seaborn  library for visualisation of the whether the data is normally distributed

# %%
import seaborn as sns

# %%
sns.pairplot(data=ipl_full)

# %% [markdown]
# ### Check the statistics of the data

# %%
ipl_full.describe()
# Out:
#                RAA         Wins      EFscore        Salary         Value
# count  2693.000000  2693.000000  2693.000000  1.925000e+03  2.693000e+03
# mean     -0.062013    -0.000224     0.057366  5.496554e+05  5.523786e+05
# std      93.934410     0.336106     0.051425  5.520085e+05  3.697348e+05
# min    -339.000000    -1.231000     0.000000  1.500000e+04 -8.798860e+05
# 25%     -53.000000    -0.190000     0.015000  1.250000e+05  3.627100e+05
# 50%     -15.000000    -0.052000     0.045000  4.000000e+05  5.026920e+05
# 75%      37.000000     0.133000     0.088000  7.500000e+05  6.814410e+05
# max     615.000000     2.041000     0.365000  3.000000e+06  2.742662e+06

# %% [markdown]
# ### Import Pycaret Library, that automatically fits teh data to different models and compares them based on many loss functions and accuracy

# %%
from pycaret.regression import *

# %% [markdown]
# ### Pass the data and target feature to the pycaret model and specify required features for tuning

# %%
reg = setup(data = ipl_full, 
            target = 'Value',
            normalize = True,
            session_id=123)
# Out:
# <style type="text/css">
# #T_c27fa_row9_col1, #T_c27fa_row13_col1 {
#   background-color: lightgreen;
# }
# </style>
# <table id="T_c27fa">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_c27fa_level0_col0" class="col_heading level0 col0" >Description</th>
#       <th id="T_c27fa_level0_col1" class="col_heading level0 col1" >Value</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_c27fa_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_c27fa_row0_col0" class="data row0 col0" >Session id</td>
#       <td id="T_c27fa_row0_col1" class="data row0 col1" >123</td>
#     </tr>
#     <tr>
#       <th id="T_c27fa_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_c27fa_row1_col0" class="data row1 col0" >Target</td>
#       <td id="T_c27fa_row1_col1" class="data row1 col1" >Value</td>
#     </tr>
#     <tr>
#       <th id="T_c27fa_level0_row2" class="row_heading level0 row2" >2</th>
#       <td id="T_c27fa_row2_col0" class="data row2 col0" >Target type</td>
#       <td id="T_c27fa_row2_col1" class="data row2 col1" >Regression</td>
#     </tr>
#     <tr>
#       <th id="T_c27fa_level0_row3" class="row_heading level0 row3" >3</th>
#       <td id="T_c27fa_row3_col0" class="data row3 col0" >Original data shape</td>
#       <td id="T_c27fa_row3_col1" class="data row3 col1" >(2693, 5)</td>
#     </tr>
#     <tr>
#       <th id="T_c27fa_level0_row4" class="row_heading level0 row4" >4</th>
#       <td id="T_c27fa_row4_col0" class="data row4 col0" >Transformed data shape</td>
#       <td id="T_c27fa_row4_col1" class="data row4 col1" >(2693, 5)</td>
#     </tr>
#     <tr>
#       <th id="T_c27fa_level0_row5" class="row_heading level0 row5" >5</th>
#       <td id="T_c27fa_row5_col0" class="data row5 col0" >Transformed train set shape</td>
#       <td id="T_c27fa_row5_col1" class="data row5 col1" >(1885, 5)</td>
#     </tr>
#     <tr>
#       <th id="T_c27fa_level0_row6" class="row_heading level0 row6" >6</th>
#       <td id="T_c27fa_row6_col0" class="data row6 col0" >Transformed test set shape</td>
#       <td id="T_c27fa_row6_col1" class="data row6 col1" >(808, 5)</td>
#     </tr>
#     <tr>
#       <th id="T_c27fa_level0_row7" class="row_heading level0 row7" >7</th>
#       <td id="T_c27fa_row7_col0" class="data row7 col0" >Numeric features</td>
#       <td id="T_c27fa_row7_col1" class="data row7 col1" >4</td>
#     </tr>
#     <tr>
#       <th id="T_c27fa_level0_row8" class="row_heading level0 row8" >8</th>
#       <td id="T_c27fa_row8_col0" class="data row8 col0" >Rows with missing values</td>
#       <td id="T_c27fa_row8_col1" class="data row8 col1" >28.5%</td>
#     </tr>
#     <tr>
#       <th id="T_c27fa_level0_row9" class="row_heading level0 row9" >9</th>
#       <td id="T_c27fa_row9_col0" class="data row9 col0" >Preprocess</td>
#       <td id="T_c27fa_row9_col1" class="data row9 col1" >True</td>
#     </tr>
#     <tr>
#       <th id="T_c27fa_level0_row10" class="row_heading level0 row10" >10</th>
#       <td id="T_c27fa_row10_col0" class="data row10 col0" >Imputation type</td>
#       <td id="T_c27fa_row10_col1" class="data row10 col1" >simple</td>
#     </tr>
#     <tr>
#       <th id="T_c27fa_level0_row11" class="row_heading level0 row11" >11</th>
#       <td id="T_c27fa_row11_col0" class="data row11 col0" >Numeric imputation</td>
#       <td id="T_c27fa_row11_col1" class="data row11 col1" >mean</td>
#     </tr>
#     <tr>
#       <th id="T_c27fa_level0_row12" class="row_heading level0 row12" >12</th>
#       <td id="T_c27fa_row12_col0" class="data row12 col0" >Categorical imputation</td>
#       <td id="T_c27fa_row12_col1" class="data row12 col1" >mode</td>
#     </tr>
#     <tr>
#       <th id="T_c27fa_level0_row13" class="row_heading level0 row13" >13</th>
#       <td id="T_c27fa_row13_col0" class="data row13 col0" >Normalize</td>
#       <td id="T_c27fa_row13_col1" class="data row13 col1" >True</td>
#     </tr>
#     <tr>
#       <th id="T_c27fa_level0_row14" class="row_heading level0 row14" >14</th>
#       <td id="T_c27fa_row14_col0" class="data row14 col0" >Normalize method</td>
#       <td id="T_c27fa_row14_col1" class="data row14 col1" >zscore</td>
#     </tr>
#     <tr>
#       <th id="T_c27fa_level0_row15" class="row_heading level0 row15" >15</th>
#       <td id="T_c27fa_row15_col0" class="data row15 col0" >Fold Generator</td>
#       <td id="T_c27fa_row15_col1" class="data row15 col1" >KFold</td>
#     </tr>
#     <tr>
#       <th id="T_c27fa_level0_row16" class="row_heading level0 row16" >16</th>
#       <td id="T_c27fa_row16_col0" class="data row16 col0" >Fold Number</td>
#       <td id="T_c27fa_row16_col1" class="data row16 col1" >10</td>
#     </tr>
#     <tr>
#       <th id="T_c27fa_level0_row17" class="row_heading level0 row17" >17</th>
#       <td id="T_c27fa_row17_col0" class="data row17 col0" >CPU Jobs</td>
#       <td id="T_c27fa_row17_col1" class="data row17 col1" >-1</td>
#     </tr>
#     <tr>
#       <th id="T_c27fa_level0_row18" class="row_heading level0 row18" >18</th>
#       <td id="T_c27fa_row18_col0" class="data row18 col0" >Use GPU</td>
#       <td id="T_c27fa_row18_col1" class="data row18 col1" >False</td>
#     </tr>
#     <tr>
#       <th id="T_c27fa_level0_row19" class="row_heading level0 row19" >19</th>
#       <td id="T_c27fa_row19_col0" class="data row19 col0" >Log Experiment</td>
#       <td id="T_c27fa_row19_col1" class="data row19 col1" >False</td>
#     </tr>
#     <tr>
#       <th id="T_c27fa_level0_row20" class="row_heading level0 row20" >20</th>
#       <td id="T_c27fa_row20_col0" class="data row20 col0" >Experiment Name</td>
#       <td id="T_c27fa_row20_col1" class="data row20 col1" >reg-default-name</td>
#     </tr>
#     <tr>
#       <th id="T_c27fa_level0_row21" class="row_heading level0 row21" >21</th>
#       <td id="T_c27fa_row21_col0" class="data row21 col0" >USI</td>
#       <td id="T_c27fa_row21_col1" class="data row21 col1" >6642</td>
#     </tr>
#   </tbody>
# </table>

# %% [markdown]
# ### comparing the results of accuracy and loss functions of different models

# %%
compare_models()
# Out:
#
#
# Initiated  . . . . . . . . . . . . . . . . . .           17:08:58
# Status     . . . . . . . . . . . . . . . . . .   Fitting 10 Folds
# Estimator  . . . . . . . . . . . . . . . . . .  Linear Regression
# <style type="text/css">
# #T_fd290 th {
#   text-align: left;
# }
# #T_fd290_row0_col0, #T_fd290_row0_col1, #T_fd290_row0_col2, #T_fd290_row0_col3, #T_fd290_row0_col5, #T_fd290_row1_col0, #T_fd290_row1_col1, #T_fd290_row1_col5, #T_fd290_row1_col6, #T_fd290_row2_col0, #T_fd290_row2_col2, #T_fd290_row2_col3, #T_fd290_row2_col5, #T_fd290_row3_col0, #T_fd290_row3_col1, #T_fd290_row3_col2, #T_fd290_row3_col3, #T_fd290_row3_col5, #T_fd290_row3_col6, #T_fd290_row4_col0, #T_fd290_row4_col1, #T_fd290_row4_col2, #T_fd290_row4_col3, #T_fd290_row4_col5, #T_fd290_row4_col6, #T_fd290_row5_col0, #T_fd290_row5_col1, #T_fd290_row5_col2, #T_fd290_row5_col3, #T_fd290_row5_col4, #T_fd290_row5_col5, #T_fd290_row5_col6, #T_fd290_row6_col0, #T_fd290_row6_col1, #T_fd290_row6_col2, #T_fd290_row6_col3, #T_fd290_row6_col4, #T_fd290_row6_col5, #T_fd290_row6_col6, #T_fd290_row7_col0, #T_fd290_row7_col1, #T_fd290_row7_col2, #T_fd290_row7_col3, #T_fd290_row7_col4, #T_fd290_row7_col6, #T_fd290_row8_col0, #T_fd290_row8_col1, #T_fd290_row8_col2, #T_fd290_row8_col3, #T_fd290_row8_col4, #T_fd290_row8_col5, #T_fd290_row8_col6, #T_fd290_row9_col0, #T_fd290_row9_col1, #T_fd290_row9_col2, #T_fd290_row9_col3, #T_fd290_row9_col4, #T_fd290_row9_col5, #T_fd290_row9_col6, #T_fd290_row10_col0, #T_fd290_row10_col1, #T_fd290_row10_col2, #T_fd290_row10_col3, #T_fd290_row10_col4, #T_fd290_row10_col5, #T_fd290_row10_col6, #T_fd290_row11_col0, #T_fd290_row11_col1, #T_fd290_row11_col2, #T_fd290_row11_col3, #T_fd290_row11_col4, #T_fd290_row11_col5, #T_fd290_row11_col6, #T_fd290_row12_col0, #T_fd290_row12_col1, #T_fd290_row12_col2, #T_fd290_row12_col3, #T_fd290_row12_col4, #T_fd290_row12_col5, #T_fd290_row12_col6, #T_fd290_row13_col0, #T_fd290_row13_col1, #T_fd290_row13_col2, #T_fd290_row13_col3, #T_fd290_row13_col4, #T_fd290_row13_col5, #T_fd290_row13_col6, #T_fd290_row14_col0, #T_fd290_row14_col1, #T_fd290_row14_col2, #T_fd290_row14_col3, #T_fd290_row14_col4, #T_fd290_row14_col5, #T_fd290_row14_col6, #T_fd290_row15_col0, #T_fd290_row15_col1, #T_fd290_row15_col2, #T_fd290_row15_col3, #T_fd290_row15_col4, #T_fd290_row15_col5, #T_fd290_row15_col6, #T_fd290_row16_col0, #T_fd290_row16_col1, #T_fd290_row16_col2, #T_fd290_row16_col3, #T_fd290_row16_col4, #T_fd290_row16_col5, #T_fd290_row16_col6, #T_fd290_row17_col0, #T_fd290_row17_col1, #T_fd290_row17_col2, #T_fd290_row17_col3, #T_fd290_row17_col4, #T_fd290_row17_col5, #T_fd290_row17_col6, #T_fd290_row18_col0, #T_fd290_row18_col1, #T_fd290_row18_col2, #T_fd290_row18_col3, #T_fd290_row18_col4, #T_fd290_row18_col5, #T_fd290_row18_col6 {
#   text-align: left;
# }
# #T_fd290_row0_col4, #T_fd290_row0_col6, #T_fd290_row1_col2, #T_fd290_row1_col3, #T_fd290_row1_col4, #T_fd290_row2_col1, #T_fd290_row2_col4, #T_fd290_row2_col6, #T_fd290_row3_col4, #T_fd290_row4_col4, #T_fd290_row7_col5 {
#   text-align: left;
#   background-color: yellow;
# }
# #T_fd290_row0_col7, #T_fd290_row1_col7, #T_fd290_row2_col7, #T_fd290_row3_col7, #T_fd290_row4_col7, #T_fd290_row5_col7, #T_fd290_row6_col7, #T_fd290_row7_col7, #T_fd290_row8_col7, #T_fd290_row9_col7, #T_fd290_row10_col7, #T_fd290_row11_col7, #T_fd290_row12_col7, #T_fd290_row13_col7, #T_fd290_row14_col7, #T_fd290_row15_col7, #T_fd290_row16_col7, #T_fd290_row17_col7 {
#   text-align: left;
#   background-color: lightgrey;
# }
# #T_fd290_row18_col7 {
#   text-align: left;
#   background-color: yellow;
#   background-color: lightgrey;
# }
# </style>
# <table id="T_fd290">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_fd290_level0_col0" class="col_heading level0 col0" >Model</th>
#       <th id="T_fd290_level0_col1" class="col_heading level0 col1" >MAE</th>
#       <th id="T_fd290_level0_col2" class="col_heading level0 col2" >MSE</th>
#       <th id="T_fd290_level0_col3" class="col_heading level0 col3" >RMSE</th>
#       <th id="T_fd290_level0_col4" class="col_heading level0 col4" >R2</th>
#       <th id="T_fd290_level0_col5" class="col_heading level0 col5" >RMSLE</th>
#       <th id="T_fd290_level0_col6" class="col_heading level0 col6" >MAPE</th>
#       <th id="T_fd290_level0_col7" class="col_heading level0 col7" >TT (Sec)</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_fd290_level0_row0" class="row_heading level0 row0" >lr</th>
#       <td id="T_fd290_row0_col0" class="data row0 col0" >Linear Regression</td>
#       <td id="T_fd290_row0_col1" class="data row0 col1" >83034.9031</td>
#       <td id="T_fd290_row0_col2" class="data row0 col2" >13195032985.6000</td>
#       <td id="T_fd290_row0_col3" class="data row0 col3" >114434.7148</td>
#       <td id="T_fd290_row0_col4" class="data row0 col4" >0.9051</td>
#       <td id="T_fd290_row0_col5" class="data row0 col5" >0.4569</td>
#       <td id="T_fd290_row0_col6" class="data row0 col6" >0.3271</td>
#       <td id="T_fd290_row0_col7" class="data row0 col7" >1.1500</td>
#     </tr>
#     <tr>
#       <th id="T_fd290_level0_row1" class="row_heading level0 row1" >lasso</th>
#       <td id="T_fd290_row1_col0" class="data row1 col0" >Lasso Regression</td>
#       <td id="T_fd290_row1_col1" class="data row1 col1" >83630.8461</td>
#       <td id="T_fd290_row1_col2" class="data row1 col2" >13188479641.6000</td>
#       <td id="T_fd290_row1_col3" class="data row1 col3" >114399.3102</td>
#       <td id="T_fd290_row1_col4" class="data row1 col4" >0.9051</td>
#       <td id="T_fd290_row1_col5" class="data row1 col5" >0.4874</td>
#       <td id="T_fd290_row1_col6" class="data row1 col6" >0.3336</td>
#       <td id="T_fd290_row1_col7" class="data row1 col7" >0.0340</td>
#     </tr>
#     <tr>
#       <th id="T_fd290_level0_row2" class="row_heading level0 row2" >lar</th>
#       <td id="T_fd290_row2_col0" class="data row2 col0" >Least Angle Regression</td>
#       <td id="T_fd290_row2_col1" class="data row2 col1" >83034.8414</td>
#       <td id="T_fd290_row2_col2" class="data row2 col2" >13195014144.0000</td>
#       <td id="T_fd290_row2_col3" class="data row2 col3" >114434.6391</td>
#       <td id="T_fd290_row2_col4" class="data row2 col4" >0.9051</td>
#       <td id="T_fd290_row2_col5" class="data row2 col5" >0.4567</td>
#       <td id="T_fd290_row2_col6" class="data row2 col6" >0.3271</td>
#       <td id="T_fd290_row2_col7" class="data row2 col7" >0.0330</td>
#     </tr>
#     <tr>
#       <th id="T_fd290_level0_row3" class="row_heading level0 row3" >llar</th>
#       <td id="T_fd290_row3_col0" class="data row3 col0" >Lasso Least Angle Regression</td>
#       <td id="T_fd290_row3_col1" class="data row3 col1" >83042.4562</td>
#       <td id="T_fd290_row3_col2" class="data row3 col2" >13194907084.8000</td>
#       <td id="T_fd290_row3_col3" class="data row3 col3" >114434.0930</td>
#       <td id="T_fd290_row3_col4" class="data row3 col4" >0.9051</td>
#       <td id="T_fd290_row3_col5" class="data row3 col5" >0.4577</td>
#       <td id="T_fd290_row3_col6" class="data row3 col6" >0.3272</td>
#       <td id="T_fd290_row3_col7" class="data row3 col7" >0.0310</td>
#     </tr>
#     <tr>
#       <th id="T_fd290_level0_row4" class="row_heading level0 row4" >br</th>
#       <td id="T_fd290_row4_col0" class="data row4 col0" >Bayesian Ridge</td>
#       <td id="T_fd290_row4_col1" class="data row4 col1" >83179.6211</td>
#       <td id="T_fd290_row4_col2" class="data row4 col2" >13194806681.6000</td>
#       <td id="T_fd290_row4_col3" class="data row4 col3" >114432.0484</td>
#       <td id="T_fd290_row4_col4" class="data row4 col4" >0.9051</td>
#       <td id="T_fd290_row4_col5" class="data row4 col5" >0.4905</td>
#       <td id="T_fd290_row4_col6" class="data row4 col6" >0.3285</td>
#       <td id="T_fd290_row4_col7" class="data row4 col7" >0.0380</td>
#     </tr>
#     <tr>
#       <th id="T_fd290_level0_row5" class="row_heading level0 row5" >ridge</th>
#       <td id="T_fd290_row5_col0" class="data row5 col0" >Ridge Regression</td>
#       <td id="T_fd290_row5_col1" class="data row5 col1" >85613.9305</td>
#       <td id="T_fd290_row5_col2" class="data row5 col2" >13321015552.0000</td>
#       <td id="T_fd290_row5_col3" class="data row5 col3" >114945.8781</td>
#       <td id="T_fd290_row5_col4" class="data row5 col4" >0.9042</td>
# LinearRegression(n_jobs=-1)

# %% [markdown]
# ### Create a variable to save the parameters considered for teh catboost regressor, since it has a relatively high accuracy and low RMSe value

# %%
catboost = create_model('catboost')
# Out:
#
#
# Initiated  . . . . . . . . . . . . . . . . . .            17:10:25
# Status     . . . . . . . . . . . . . . . . . .    Fitting 10 Folds
# Estimator  . . . . . . . . . . . . . . . . . .  CatBoost Regressor
# <style type="text/css">
# #T_c2df3_row10_col0, #T_c2df3_row10_col1, #T_c2df3_row10_col2, #T_c2df3_row10_col3, #T_c2df3_row10_col4, #T_c2df3_row10_col5 {
#   background: yellow;
# }
# </style>
# <table id="T_c2df3">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_c2df3_level0_col0" class="col_heading level0 col0" >MAE</th>
#       <th id="T_c2df3_level0_col1" class="col_heading level0 col1" >MSE</th>
#       <th id="T_c2df3_level0_col2" class="col_heading level0 col2" >RMSE</th>
#       <th id="T_c2df3_level0_col3" class="col_heading level0 col3" >R2</th>
#       <th id="T_c2df3_level0_col4" class="col_heading level0 col4" >RMSLE</th>
#       <th id="T_c2df3_level0_col5" class="col_heading level0 col5" >MAPE</th>
#     </tr>
#     <tr>
#       <th class="index_name level0" >Fold</th>
#       <th class="blank col0" >&nbsp;</th>
#       <th class="blank col1" >&nbsp;</th>
#       <th class="blank col2" >&nbsp;</th>
#       <th class="blank col3" >&nbsp;</th>
#       <th class="blank col4" >&nbsp;</th>
#       <th class="blank col5" >&nbsp;</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_c2df3_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_c2df3_row0_col0" class="data row0 col0" >82518.2004</td>
#       <td id="T_c2df3_row0_col1" class="data row0 col1" >13859145649.8642</td>
#       <td id="T_c2df3_row0_col2" class="data row0 col2" >117724.8727</td>
#       <td id="T_c2df3_row0_col3" class="data row0 col3" >0.8950</td>
#       <td id="T_c2df3_row0_col4" class="data row0 col4" >0.4821</td>
#       <td id="T_c2df3_row0_col5" class="data row0 col5" >0.3108</td>
#     </tr>
#     <tr>
#       <th id="T_c2df3_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_c2df3_row1_col0" class="data row1 col0" >82542.6723</td>
#       <td id="T_c2df3_row1_col1" class="data row1 col1" >12388791573.1115</td>
#       <td id="T_c2df3_row1_col2" class="data row1 col2" >111304.9486</td>
#       <td id="T_c2df3_row1_col3" class="data row1 col3" >0.9167</td>
#       <td id="T_c2df3_row1_col4" class="data row1 col4" >0.5436</td>
#       <td id="T_c2df3_row1_col5" class="data row1 col5" >0.3753</td>
#     </tr>
#     <tr>
#       <th id="T_c2df3_level0_row2" class="row_heading level0 row2" >2</th>
#       <td id="T_c2df3_row2_col0" class="data row2 col0" >79554.8039</td>
#       <td id="T_c2df3_row2_col1" class="data row2 col1" >14833087611.0204</td>
#       <td id="T_c2df3_row2_col2" class="data row2 col2" >121791.1639</td>
#       <td id="T_c2df3_row2_col3" class="data row2 col3" >0.8935</td>
#       <td id="T_c2df3_row2_col4" class="data row2 col4" >0.3128</td>
#       <td id="T_c2df3_row2_col5" class="data row2 col5" >0.2307</td>
#     </tr>
#     <tr>
#       <th id="T_c2df3_level0_row3" class="row_heading level0 row3" >3</th>
#       <td id="T_c2df3_row3_col0" class="data row3 col0" >74794.3297</td>
#       <td id="T_c2df3_row3_col1" class="data row3 col1" >9535346814.6372</td>
#       <td id="T_c2df3_row3_col2" class="data row3 col2" >97649.1004</td>
#       <td id="T_c2df3_row3_col3" class="data row3 col3" >0.9282</td>
#       <td id="T_c2df3_row3_col4" class="data row3 col4" >0.4656</td>
#       <td id="T_c2df3_row3_col5" class="data row3 col5" >0.6287</td>
#     </tr>
#     <tr>
#       <th id="T_c2df3_level0_row4" class="row_heading level0 row4" >4</th>
#       <td id="T_c2df3_row4_col0" class="data row4 col0" >88981.0832</td>
#       <td id="T_c2df3_row4_col1" class="data row4 col1" >16211257367.2945</td>
#       <td id="T_c2df3_row4_col2" class="data row4 col2" >127323.4360</td>
#       <td id="T_c2df3_row4_col3" class="data row4 col3" >0.8911</td>
#       <td id="T_c2df3_row4_col4" class="data row4 col4" >0.5631</td>
#       <td id="T_c2df3_row4_col5" class="data row4 col5" >0.7860</td>
#     </tr>
#     <tr>
#       <th id="T_c2df3_level0_row5" class="row_heading level0 row5" >5</th>
#       <td id="T_c2df3_row5_col0" class="data row5 col0" >80896.1040</td>
#       <td id="T_c2df3_row5_col1" class="data row5 col1" >12813521921.9057</td>
#       <td id="T_c2df3_row5_col2" class="data row5 col2" >113196.8282</td>
#       <td id="T_c2df3_row5_col3" class="data row5 col3" >0.9101</td>
#       <td id="T_c2df3_row5_col4" class="data row5 col4" >0.3538</td>
#       <td id="T_c2df3_row5_col5" class="data row5 col5" >0.2717</td>
#     </tr>
#     <tr>
#       <th id="T_c2df3_level0_row6" class="row_heading level0 row6" >6</th>
#       <td id="T_c2df3_row6_col0" class="data row6 col0" >65069.8604</td>
#       <td id="T_c2df3_row6_col1" class="data row6 col1" >7928512578.1020</td>
#       <td id="T_c2df3_row6_col2" class="data row6 col2" >89042.1955</td>
#       <td id="T_c2df3_row6_col3" class="data row6 col3" >0.9093</td>
#       <td id="T_c2df3_row6_col4" class="data row6 col4" >0.2998</td>
#       <td id="T_c2df3_row6_col5" class="data row6 col5" >0.2310</td>
#     </tr>
#     <tr>
#       <th id="T_c2df3_level0_row7" class="row_heading level0 row7" >7</th>
#       <td id="T_c2df3_row7_col0" class="data row7 col0" >103636.2400</td>
#       <td id="T_c2df3_row7_col1" class="data row7 col1" >21707418138.1585</td>
#       <td id="T_c2df3_row7_col2" class="data row7 col2" >147334.3753</td>
#       <td id="T_c2df3_row7_col3" class="data row7 col3" >0.8938</td>
#       <td id="T_c2df3_row7_col4" class="data row7 col4" >0.3778</td>
#       <td id="T_c2df3_row7_col5" class="data row7 col5" >0.3095</td>
#     </tr>
#     <tr>
#       <th id="T_c2df3_level0_row8" class="row_heading level0 row8" >8</th>
#       <td id="T_c2df3_row8_col0" class="data row8 col0" >81609.4085</td>
#       <td id="T_c2df3_row8_col1" class="data row8 col1" >12075357359.4932</td>
#       <td id="T_c2df3_row8_col2" class="data row8 col2" >109887.9309</td>
#       <td id="T_c2df3_row8_col3" class="data row8 col3" >0.8979</td>
#       <td id="T_c2df3_row8_col4" class="data row8 col4" >0.3080</td>
#       <td id="T_c2df3_row8_col5" class="data row8 col5" >0.2007</td>
#     </tr>
#     <tr>
#       <th id="T_c2df3_level0_row9" class="row_heading level0 row9" >9</th>
#       <td id="T_c2df3_row9_col0" class="data row9 col0" >95203.6155</td>
#       <td id="T_c2df3_row9_col1" class="data row9 col1" >19389830545.0631</td>
#       <td id="T_c2df3_row9_col2" class="data row9 col2" >139247.3718</td>
#       <td id="T_c2df3_row9_col3" class="data row9 col3" >0.8667</td>
#       <td id="T_c2df3_row9_col4" class="data row9 col4" >0.5253</td>
#       <td id="T_c2df3_row9_col5" class="data row9 col5" >0.4104</td>
#     </tr>
#     <tr>
#       <th id="T_c2df3_level0_row10" class="row_heading level0 row10" >Mean</th>
#       <td id="T_c2df3_row10_col0" class="data row10 col0" >83480.6318</td>
#       <td id="T_c2df3_row10_col1" class="data row10 col1" >14074226955.8650</td>
#       <td id="T_c2df3_row10_col2" class="data row10 col2" >117450.2223</td>
#       <td id="T_c2df3_row10_col3" class="data row10 col3" >0.9002</td>
#       <td id="T_c2df3_row10_col4" class="data row10 col4" >0.4232</td>
#       <td id="T_c2df3_row10_col5" class="data row10 col5" >0.3755</td>
#     </tr>
#     <tr>
#       <th id="T_c2df3_level0_row11" class="row_heading level0 row11" >Std</th>
#       <td id="T_c2df3_row11_col0" class="data row11 col0" >10078.3909</td>
#       <td id="T_c2df3_row11_col1" class="data row11 col1" >3981294576.0055</td>
#       <td id="T_c2df3_row11_col2" class="data row11 col2" >16723.4037</td>
#       <td id="T_c2df3_row11_col3" class="data row11 col3" >0.0160</td>
#       <td id="T_c2df3_row11_col4" class="data row11 col4" >0.0987</td>
#       <td id="T_c2df3_row11_col5" class="data row11 col5" >0.1804</td>
#     </tr>
#   </tbody>
# </table>

# %% [markdown]
# ### Fetching the parameters of the catboost regressor

# %%
catboost.get_params()
# Out:
# {'loss_function': 'RMSE',
#  'border_count': 254,
#  'verbose': False,
#  'task_type': 'CPU',
#  'random_state': 123}

# %% [markdown]
# ### Hyper parameter tuning for the catboost regressor model

# %%
catboost_tune=tune_model(catboost)
# Out:
#
#
# Initiated  . . . . . . . . . . . . . . . . . .              17:10:59
# Status     . . . . . . . . . . . . . . . . . .  Loading Dependencies
# Estimator  . . . . . . . . . . . . . . . . . .    CatBoost Regressor
# <style type="text/css">
# #T_ed2da_row10_col0, #T_ed2da_row10_col1, #T_ed2da_row10_col2, #T_ed2da_row10_col3, #T_ed2da_row10_col4, #T_ed2da_row10_col5 {
#   background: yellow;
# }
# </style>
# <table id="T_ed2da">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_ed2da_level0_col0" class="col_heading level0 col0" >MAE</th>
#       <th id="T_ed2da_level0_col1" class="col_heading level0 col1" >MSE</th>
#       <th id="T_ed2da_level0_col2" class="col_heading level0 col2" >RMSE</th>
#       <th id="T_ed2da_level0_col3" class="col_heading level0 col3" >R2</th>
#       <th id="T_ed2da_level0_col4" class="col_heading level0 col4" >RMSLE</th>
#       <th id="T_ed2da_level0_col5" class="col_heading level0 col5" >MAPE</th>
#     </tr>
#     <tr>
#       <th class="index_name level0" >Fold</th>
#       <th class="blank col0" >&nbsp;</th>
#       <th class="blank col1" >&nbsp;</th>
#       <th class="blank col2" >&nbsp;</th>
#       <th class="blank col3" >&nbsp;</th>
#       <th class="blank col4" >&nbsp;</th>
#       <th class="blank col5" >&nbsp;</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_ed2da_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_ed2da_row0_col0" class="data row0 col0" >83880.8196</td>
#       <td id="T_ed2da_row0_col1" class="data row0 col1" >12507774949.3415</td>
#       <td id="T_ed2da_row0_col2" class="data row0 col2" >111838.1641</td>
#       <td id="T_ed2da_row0_col3" class="data row0 col3" >0.9053</td>
#       <td id="T_ed2da_row0_col4" class="data row0 col4" >0.4805</td>
#       <td id="T_ed2da_row0_col5" class="data row0 col5" >0.3345</td>
#     </tr>
#     <tr>
#       <th id="T_ed2da_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_ed2da_row1_col0" class="data row1 col0" >81683.6669</td>
#       <td id="T_ed2da_row1_col1" class="data row1 col1" >11309959329.1912</td>
#       <td id="T_ed2da_row1_col2" class="data row1 col2" >106348.2926</td>
#       <td id="T_ed2da_row1_col3" class="data row1 col3" >0.9240</td>
#       <td id="T_ed2da_row1_col4" class="data row1 col4" >0.4266</td>
#       <td id="T_ed2da_row1_col5" class="data row1 col5" >0.3933</td>
#     </tr>
#     <tr>
#       <th id="T_ed2da_level0_row2" class="row_heading level0 row2" >2</th>
#       <td id="T_ed2da_row2_col0" class="data row2 col0" >83395.5732</td>
#       <td id="T_ed2da_row2_col1" class="data row2 col1" >13904715851.6614</td>
#       <td id="T_ed2da_row2_col2" class="data row2 col2" >117918.2592</td>
#       <td id="T_ed2da_row2_col3" class="data row2 col3" >0.9001</td>
#       <td id="T_ed2da_row2_col4" class="data row2 col4" >0.3502</td>
#       <td id="T_ed2da_row2_col5" class="data row2 col5" >0.2608</td>
#     </tr>
#     <tr>
#       <th id="T_ed2da_level0_row3" class="row_heading level0 row3" >3</th>
#       <td id="T_ed2da_row3_col0" class="data row3 col0" >80347.1699</td>
#       <td id="T_ed2da_row3_col1" class="data row3 col1" >10771959359.9244</td>
#       <td id="T_ed2da_row3_col2" class="data row3 col2" >103788.0502</td>
#       <td id="T_ed2da_row3_col3" class="data row3 col3" >0.9188</td>
#       <td id="T_ed2da_row3_col4" class="data row3 col4" >0.5945</td>
#       <td id="T_ed2da_row3_col5" class="data row3 col5" >0.6485</td>
#     </tr>
#     <tr>
#       <th id="T_ed2da_level0_row4" class="row_heading level0 row4" >4</th>
#       <td id="T_ed2da_row4_col0" class="data row4 col0" >93545.2834</td>
#       <td id="T_ed2da_row4_col1" class="data row4 col1" >17763481130.3868</td>
#       <td id="T_ed2da_row4_col2" class="data row4 col2" >133279.7101</td>
#       <td id="T_ed2da_row4_col3" class="data row4 col3" >0.8807</td>
#       <td id="T_ed2da_row4_col4" class="data row4 col4" >0.4917</td>
#       <td id="T_ed2da_row4_col5" class="data row4 col5" >0.7489</td>
#     </tr>
#     <tr>
#       <th id="T_ed2da_level0_row5" class="row_heading level0 row5" >5</th>
#       <td id="T_ed2da_row5_col0" class="data row5 col0" >86219.1733</td>
#       <td id="T_ed2da_row5_col1" class="data row5 col1" >13250210407.5540</td>
#       <td id="T_ed2da_row5_col2" class="data row5 col2" >115109.5583</td>
#       <td id="T_ed2da_row5_col3" class="data row5 col3" >0.9070</td>
#       <td id="T_ed2da_row5_col4" class="data row5 col4" >0.4111</td>
#       <td id="T_ed2da_row5_col5" class="data row5 col5" >0.3002</td>
#     </tr>
#     <tr>
#       <th id="T_ed2da_level0_row6" class="row_heading level0 row6" >6</th>
#       <td id="T_ed2da_row6_col0" class="data row6 col0" >70065.1984</td>
#       <td id="T_ed2da_row6_col1" class="data row6 col1" >8430227576.7550</td>
#       <td id="T_ed2da_row6_col2" class="data row6 col2" >91816.2708</td>
#       <td id="T_ed2da_row6_col3" class="data row6 col3" >0.9036</td>
#       <td id="T_ed2da_row6_col4" class="data row6 col4" >0.3084</td>
#       <td id="T_ed2da_row6_col5" class="data row6 col5" >0.2415</td>
#     </tr>
#     <tr>
#       <th id="T_ed2da_level0_row7" class="row_heading level0 row7" >7</th>
#       <td id="T_ed2da_row7_col0" class="data row7 col0" >105954.5935</td>
#       <td id="T_ed2da_row7_col1" class="data row7 col1" >21157787808.6832</td>
#       <td id="T_ed2da_row7_col2" class="data row7 col2" >145457.1683</td>
#       <td id="T_ed2da_row7_col3" class="data row7 col3" >0.8965</td>
#       <td id="T_ed2da_row7_col4" class="data row7 col4" >0.3619</td>
#       <td id="T_ed2da_row7_col5" class="data row7 col5" >0.3291</td>
#     </tr>
#     <tr>
#       <th id="T_ed2da_level0_row8" class="row_heading level0 row8" >8</th>
#       <td id="T_ed2da_row8_col0" class="data row8 col0" >83975.0883</td>
#       <td id="T_ed2da_row8_col1" class="data row8 col1" >11913898726.7528</td>
#       <td id="T_ed2da_row8_col2" class="data row8 col2" >109150.8073</td>
#       <td id="T_ed2da_row8_col3" class="data row8 col3" >0.8993</td>
#       <td id="T_ed2da_row8_col4" class="data row8 col4" >0.5220</td>
#       <td id="T_ed2da_row8_col5" class="data row8 col5" >0.2128</td>
#     </tr>
#     <tr>
#       <th id="T_ed2da_level0_row9" class="row_heading level0 row9" >9</th>
#       <td id="T_ed2da_row9_col0" class="data row9 col0" >95302.2801</td>
#       <td id="T_ed2da_row9_col1" class="data row9 col1" >18831233889.3404</td>
#       <td id="T_ed2da_row9_col2" class="data row9 col2" >137226.9430</td>
#       <td id="T_ed2da_row9_col3" class="data row9 col3" >0.8706</td>
#       <td id="T_ed2da_row9_col4" class="data row9 col4" >0.5220</td>
#       <td id="T_ed2da_row9_col5" class="data row9 col5" >0.4492</td>
#     </tr>
#     <tr>
#       <th id="T_ed2da_level0_row10" class="row_heading level0 row10" >Mean</th>
#       <td id="T_ed2da_row10_col0" class="data row10 col0" >86436.8847</td>
#       <td id="T_ed2da_row10_col1" class="data row10 col1" >13984124902.9591</td>
#       <td id="T_ed2da_row10_col2" class="data row10 col2" >117193.3224</td>
#       <td id="T_ed2da_row10_col3" class="data row10 col3" >0.9006</td>
#       <td id="T_ed2da_row10_col4" class="data row10 col4" >0.4469</td>
#       <td id="T_ed2da_row10_col5" class="data row10 col5" >0.3919</td>
#     </tr>
#     <tr>
#       <th id="T_ed2da_level0_row11" class="row_heading level0 row11" >Std</th>
#       <td id="T_ed2da_row11_col0" class="data row11 col0" >9271.8187</td>
#       <td id="T_ed2da_row11_col1" class="data row11 col1" >3802167341.0912</td>
#       <td id="T_ed2da_row11_col2" class="data row11 col2" >15806.6471</td>
#       <td id="T_ed2da_row11_col3" class="data row11 col3" >0.0151</td>
#       <td id="T_ed2da_row11_col4" class="data row11 col4" >0.0858</td>
#       <td id="T_ed2da_row11_col5" class="data row11 col5" >0.1685</td>
#     </tr>
#   </tbody>
# </table>
# Fitting 10 folds for each of 10 candidates, totalling 100 fits

# %%
print(catboost_tune)
# Out:
# <catboost.core.CatBoostRegressor object at 0x000001F15DD9FCD0>

# %% [markdown]
# ### Evaluating the cat boost model

# %%
evaluate_model(catboost_tune)
# Out:
# interactive(children=(ToggleButtons(description='Plot Type:', icons=('',), options=(('Pipeline Plot', 'pipelin…

# %% [markdown]
# ### Use the model to predict the IPL Player value and check the error values

# %%
predict_model(catboost_tune);
# Out:
# <style type="text/css">
# </style>
# <table id="T_a38ff">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_a38ff_level0_col0" class="col_heading level0 col0" >Model</th>
#       <th id="T_a38ff_level0_col1" class="col_heading level0 col1" >MAE</th>
#       <th id="T_a38ff_level0_col2" class="col_heading level0 col2" >MSE</th>
#       <th id="T_a38ff_level0_col3" class="col_heading level0 col3" >RMSE</th>
#       <th id="T_a38ff_level0_col4" class="col_heading level0 col4" >R2</th>
#       <th id="T_a38ff_level0_col5" class="col_heading level0 col5" >RMSLE</th>
#       <th id="T_a38ff_level0_col6" class="col_heading level0 col6" >MAPE</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_a38ff_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_a38ff_row0_col0" class="data row0 col0" >CatBoost Regressor</td>
#       <td id="T_a38ff_row0_col1" class="data row0 col1" >85442.0525</td>
#       <td id="T_a38ff_row0_col2" class="data row0 col2" >13342181639.3645</td>
#       <td id="T_a38ff_row0_col3" class="data row0 col3" >115508.3618</td>
#       <td id="T_a38ff_row0_col4" class="data row0 col4" >0.8951</td>
#       <td id="T_a38ff_row0_col5" class="data row0 col5" >0.4512</td>
#       <td id="T_a38ff_row0_col6" class="data row0 col6" >0.5650</td>
#     </tr>
#   </tbody>
# </table>

# %% [markdown]
# ### Finalise the catboost model

# %%
final_catboost = finalize_model(catboost_tune)

# %% [markdown]
# ### Importing the pickle file, in order to use it during deployment of the model

# %%
import pickle

# %% [markdown]
# ### Dump the created final cat boost mmodel to the pickle file

# %%
pickle.dump(final_catboost,open('ipl.pkl','wb'))
